# %% [markdown]
# ## Lab: Data Visualization

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
sns.set()
tips = sns.load_dataset('tips')
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x='tip', y='total_bill', hue=tips.tip.tolist(), data=tips);
plt.legend('ABCDEF', ncol=2, loc='lower right');

# %%
tip_sums = tips.groupby('tip', as_index=False).sum()
tip_mean = tips.groupby('tip', as_index=False).mean()
tip_sums
# Out:
#        tip  total_bill  size
# 0     1.00       28.67     6
# 1     1.01       16.99     2
# 2     1.10       12.90     2
# 3     1.17       32.83     2
# 4     1.25       29.09     6
# ..     ...         ...   ...
# 118   6.70       34.30     6
# 119   6.73       48.27     4
# 120   7.58       39.42     4
# 121   9.00       48.33     4
# 122  10.00       50.81     3
#
# [123 rows x 3 columns]

# %%
tip_mean
# Out:
#        tip  total_bill  size
# 0     1.00    7.167500   1.5
# 1     1.01   16.990000   2.0
# 2     1.10   12.900000   2.0
# 3     1.17   32.830000   2.0
# 4     1.25    9.696667   2.0
# ..     ...         ...   ...
# 118   6.70   34.300000   6.0
# 119   6.73   48.270000   4.0
# 120   7.58   39.420000   4.0
# 121   9.00   48.330000   4.0
# 122  10.00   50.810000   3.0
#
# [123 rows x 3 columns]

# %%
sns.relplot(x='tip', y='total_bill',hue=tip_sums.tip.tolist(), data=tip_sums);
plt.legend('ABCDEF', ncol=2, loc='upper right');

# %%
sns.relplot(x='tip', y='total_bill',hue=tip_mean.tip.tolist(), data=tip_mean);
plt.legend('ABCDEF', ncol=2, loc='lower right');

# %%
sns.lmplot(x='tip', y='total_bill', data=tip_sums);
plt.legend('ABCDEF', ncol=2, loc='upper right');

# %%
sns.lmplot(x='tip', y='total_bill', data=tip_mean);
plt.legend('ABCDEF', ncol=2, loc='lower right');

# %%
graph = sns.barplot(x='tip', y='total_bill', data=tip_mean,ci=None);
graph.set_xticklabels(labels=list("")[1:]);
plt.legend('ABCDEF', ncol=2, loc='upper left');

# %%
sns.relplot(x='tip', y='total_bill',hue=tip_mean.tip.tolist(), data=tip_mean);
plt.legend('ABCDEF', ncol=2, loc='upper left');

# %%
sns.distplot(tips['tip'])
sns.distplot(tips['total_bill']);
plt.legend('ABCDEF', ncol=2, loc='upper right');
# Out:
# /home/aya/data-visulization/.venv/lib/python3.9/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/aya/data-visulization/.venv/lib/python3.9/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
with sns.axes_style('white'):
    sns.jointplot("tip", "total_bill", tips, kind='kde');
    plt.legend('ABCDEF', ncol=2, loc='upper right');
# Out:
# /home/aya/data-visulization/.venv/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
with sns.axes_style('white'):
    sns.jointplot("tip", "total_bill", tips, kind='hex');
    plt.legend('ABCDEF', ncol=2, loc='upper right');
# Out:
# /home/aya/data-visulization/.venv/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Summary:
#
# - How to use the different libraries like Pandas. matplotlib, numpy, seaborn.
# - how to visualize the data.
# - how to use different plotting to visualize the data.
# - how to deal with analysis the data using Pandas library.
# - How to load data file(s) using Pandas.
# - How to convert a variable to a different data type.
# - How to transpose a Data set or dataframe using Pandas.
# - How to sort a Pandas DataFrame.
# - How to group variables in Pandas to calculate count, average, sum.
# - How to summarize the distribution of variables using bar charts, histograms, and box and whisker plots.
# - How to summarize relationships using line plots and scatter plots.
# - How to compare the distribution and relationships of variables for different class values on the same plot.
